# %%
import csv
import json
 
 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['recipe_id']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'Recipesz.csv'
jsonFilePath = r'Names.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 38
#      35 jsonFilePath = r'Names.json'
#      37 # Call the make_json function
# ---> 38 make_json(csvFilePath, jsonFilePath)
#
# Cell In[3], line 22, in make_json(csvFilePath, jsonFilePath)
#      16     # Convert each row into a dictionary
#      17     # and add it to data
#      18     for rows in csvReader:
#      19
#      20         # Assuming a column named 'No' to
#      21         # be the primary key
# ---> 22         key = rows['recipe_id']
#      23         data[key] = rows
#      25 # Open a json writer, and use the json.dumps()
#      26 # function to dump data
#
# KeyError: 'recipe_id'

# %%
dict = [""]

# %%
import csv
import json
 
 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
        i = 0
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = i
            temp = rows['Ingredients']
            templist = temp.split(", ")
            rows['Ingredients'] = templist
            data[key] = rows
            i=i+1
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'recipesimg.csv'
jsonFilePath = r'Names3.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
# Imports the Google Cloud client library
from google.cloud import storage

# Instantiates a client
client = storage.Client()

# The name for the new bucket
bucket_name = "somethingaldieric"

# Creates the new bucket
bucket = client.create_bucket(bucket_name)

print(f"Bucket {bucket.name} created.")
# Out:
# c:\Users\adri\.pyenv\pyenv-win\versions\3.9.13\lib\site-packages\google\auth\_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Bucket somethingaldieric created.

# %%
# Imports the Google Cloud client library
from google.cloud import storage

# Instantiates a client
client = storage.Client()

# The name for the new bucket
bucket_name = "somethingaldieric"

bucket = client.get_bucket(bucket_name)
filesomething = "images/33768_erin_m_d833b036-a8da-4157-bdfe-19717901f4f5.png"
blob = bucket.blob(filesomething)
blob.upload_from_filename(filesomething)
# Out:
# c:\Users\adri\.pyenv\pyenv-win\versions\3.9.13\lib\site-packages\google\auth\_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
import csv
import json
import requests # to get image from the web
import shutil # to save it locally
import os

 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
    
    image_folder = 'images'
    if not os.path.exists(image_folder):
        os.makedirs(image_folder)
    
    # Imports the Google Cloud client library
    client = storage.Client()

    # Instantiates a bucket
    bucket_name = "somethingaldieric"
    bucket = client.get_bucket(bucket_name)

    cstorage_base_url = "https://storage.googleapis.com/somethingaldieric/images%5C"
    
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
        i = 0
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = i
            data[key] = rows
            i=i+1
            
            # download image
            url = rows['Image']
            r = requests.get(url, stream = True)
            savefile = url.split("/")[-1]
            filename = os.path.join(image_folder, url.split("/")[-1])

            print(filename)

            # Upload to bucket
            blob = bucket.blob(filename)
            blob.upload_from_filename(filename)

            if r.status_code == 200:
                # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
                r.raw.decode_content = True
                
                # Open a local file with wb ( write binary ) permission.
                with open(filename,'wb') as f:
                    shutil.copyfileobj(r.raw, f)
                    
                print('Image sucessfully Downloaded: ',filename)
            else:
                print('Image Couldn\'t be retreived')
            

            
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'dupe.csv'
jsonFilePath = r'Names3.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 81
#      78 jsonFilePath = r'Names3.json'
#      80 # Call the make_json function
# ---> 81 make_json(csvFilePath, jsonFilePath)
#
# Cell In[1], line 20, in make_json(csvFilePath, jsonFilePath)
#      17     os.makedirs(image_folder)
#      19 # Imports the Google Cloud client library
# ---> 20 client = storage.Client()
#      22 # Instantiates a bucket
#      23 bucket_name = "somethingaldieric"
#
# NameError: name 'storage' is not defined

# %%
import csv
import json
import requests # to get image from the web
import shutil # to save it locally
import os
 
 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}

    image_folder = 'images'
    if not os.path.exists(image_folder):
        os.makedirs(image_folder)
    
    # Imports the Google Cloud client library
    client = storage.Client()

    # Instantiates a bucket
    bucket_name = "somethingaldieric"
    bucket = client.get_bucket(bucket_name)

    cstorage_base_url = f"https://storage.googleapis.com/{bucket_name}/"
    print(cstorage_base_url)
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
        i = 0
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = i

            # download image
            url = rows['Image']
            r = requests.get(url, stream = True)
            savefile = url.split("/")[-1]
            filename = os.path.join(image_folder, url.split("/")[-1])

            # uncomment this if you're on windows
            filename = filename.replace(os.sep, '/')
            print(filename)

            # Upload to bucket
            blob = bucket.blob(filename)
            blob.upload_from_filename(filename)

            # change Image url
            rows['Image'] = cstorage_base_url + savefile

            temp = rows['Ingredients']
            templist = temp.split(", ")
            rows['Ingredients'] = templist
            data[key] = rows
            i=i+1
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'dupe2.csv'
jsonFilePath = r'Names3.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
# Out:
# https://storage.googleapis.com/somethingaldieric/images%5C
# images/33768_erin_m_d833b036-a8da-4157-bdfe-19717901f4f5.png
# images/34077_erin_m_dfdd51aa-b93b-40fd-b6de-05eb11f7ce8a.png
# images/34083_tabitharwheeler_6f1df1ad-953a-4ff1-b83b-a4254d944fcc.jpg

# %%
import csv
import json
import requests # to get image from the web
import shutil # to save it locally
import os
from google.cloud import storage

# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}

    image_folder = 'images'
    if not os.path.exists(image_folder):
        os.makedirs(image_folder)
    
    # Imports the Google Cloud client library
    client = storage.Client()

    # Instantiates a bucket
    bucket_name = "somethingaldieric"
    bucket = client.get_bucket(bucket_name)

    cstorage_base_url = f"https://storage.googleapis.com/{bucket_name}/"
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
        i = 0
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = i

            # download image
            url = rows['Image']
            savefile = url.split("/")[-1]
            filename = os.path.join(image_folder, url.split("/")[-1])

            r = requests.get(url, stream = True)

            if r.status_code == 200:
                # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
                r.raw.decode_content = True
                
                # Open a local file with wb ( write binary ) permission.
                with open(filename,'wb') as f:
                    shutil.copyfileobj(r.raw, f)
                    
                print('Image sucessfully Downloaded: ',filename)
            else:
                print('Image Couldn\'t be retreived')
            
            # uncomment this if you're on windows
            filename = filename.replace(os.sep, '/')
            print(filename)

            # Upload to bucket
            blob = bucket.blob(filename)
            blob.upload_from_filename(filename)

            # change Image url
            rows['Image'] = cstorage_base_url + savefile

            temp = rows['Ingredients']
            templist = temp.split(", ")
            rows['Ingredients'] = templist
            data[key] = rows
            i=i+1
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'input.csv'
jsonFilePath = r'Names3.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
# Out:
# Image sucessfully Downloaded:  images/33768_erin_m_d833b036-a8da-4157-bdfe-19717901f4f5.png
# images/33768_erin_m_d833b036-a8da-4157-bdfe-19717901f4f5.png
# Image sucessfully Downloaded:  images/34077_erin_m_dfdd51aa-b93b-40fd-b6de-05eb11f7ce8a.png
# images/34077_erin_m_dfdd51aa-b93b-40fd-b6de-05eb11f7ce8a.png
# Image sucessfully Downloaded:  images/34083_tabitharwheeler_6f1df1ad-953a-4ff1-b83b-a4254d944fcc.jpg
# images/34083_tabitharwheeler_6f1df1ad-953a-4ff1-b83b-a4254d944fcc.jpg
# Bad pipe message: %s [b'\xcf\x88\xe1+3\xcb\xea\x82\xdc\x15(sXiO\xe3\xd0: \xff\x84\xc5\xc6\x07\xc2\xf5\xdf\x8byo?\xa5\x88\xf6~\x12W:\xbb\x8aN\rb\xf0\xc1\xca\x81\xafk\xfa\x9d\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00', b'\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08']
# Bad pipe message: %s [b'\x08\n\x08\x0b\x08\x04\x08', b'\x06\x04\x01\x05']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b"\x90\xa2\x8chJ\x87\xf5\x1c)\x8a\xd5k'\x99\xd5\x1d!\x81\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\", b"\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08"]
# Bad pipe message: %s [b"\x1d\x96\xac\x81B\x9a\x86\x15\xd5\xc0|R\x98r\xdft\x08*\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n", b'\x08\x04\x08\x05\x08\x06\x04', b'', b'']
# Bad pipe message: %s [b"\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 i\x03\x0c{\xfd\x15S\xec'c\xea\xd7\n\xf4\xe8\xa5y.\xde\xbc\xed\xcb"]
# Bad pipe message: %s [b'\n\x08\x0b\x08\x04\x08\x05\x08']
# Bad pipe message: %s [b'', b'\x03\x03']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x01\x05\x01\x06\x01']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x02\x03', b'\x02\x01', b'\x02\x02']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b"V\xdak7-g\xa7\xb1\x87d_\x11F\x1a\xec4\xfc<\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0", b'\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r']
